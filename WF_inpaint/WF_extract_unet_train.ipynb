# %% [markdown]
# # <center> Wavefront set extraction </center>

# %% [markdown]
# In this notebook we are attempting to perfomr wavefront set extraction via UNet

# %%
# %matplotlib inline
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Import the needed modules
from data.data_factory import generate_data_WF, DataGenerator_WF
from ellipse.ellipseWF_factory import plot_WF 

import matplotlib.pyplot as plt
import numpy.random as rnd
import numpy as np
import odl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data generator

# %%
batch_size = 1
size = 256
nClasses = 180

# %%
y_arr, x_true_arr = generate_data_WF(batch_size, size, nClasses)

# %%
plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(y_arr[0,:,:,0], cmap = "gray")

# %%
plt.figure(figsize=(6,6))
plt.axis('off')
plot_WF(x_true_arr[0,:,:,0])

# %% [markdown]
# ## Load the model

# %%
# Tensorflow and seed
seed_value = 0
import random
random.seed(seed_value)
import tensorflow as tf
tf.set_random_seed(seed_value)

# Importing relevant keras modules
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.models import load_model
from shared.shared import create_increasing_dir
import pickle

# %%
# Import model and custom losses
from models.unet import UNet
from models.losses import CUSTOM_OBJECTS

# %%
# Parameters for the training
learning_rate = 1e-3
loss = 'mae'
batch_size = 50
epoches = 10000

# %%
pretrained = 0
# path_to_model_dir = './models/unets_WF/training_0'

# %%
# Data generator
size = 256
nClasses = 180
train_gen = DataGenerator_WF(batch_size, size, nClasses)
val_gen = DataGenerator_WF(batch_size, size, nClasses)

# %%
if pretrained==0:
    # Create a fresh model
    print("Create a fresh model")
    unet = UNet()
    model = unet.create_model( img_shape = (size, size, 1) , loss = loss, learning_rate = learning_rate)
    path_to_training = create_increasing_dir('./models/unets_WF', 'training')
    print("Save training in {}".format(path_to_training))
    path_to_model_dir = path_to_training
    
else: 
    print("Use trained model as initialization:")
    print(path_to_model_dir+"/weights.hdf5")
    model = load_model(path_to_model_dir+"/weights.hdf5",
                       custom_objects=CUSTOM_OBJECTS)
    path_to_training = path_to_model_dir
# Out:
# Create a fresh model
# build UNet ...
# WARNING:tensorflow:From /homes/extern/andrade/store/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1184: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# Save training in ./models/unets/training_6

# %%
# Callbacks for saving model
context = {
    "loss": loss,
    "batch_size": batch_size,
    "learning_rate": learning_rate,
    "path_to_model_dir": path_to_model_dir,
}
path_to_context = path_to_training+'/context.log'

with open(path_to_context, 'wb') as dict_items_save:
    pickle.dump(context, dict_items_save)
print("Save training context to {}".format(path_to_context))

# Save architecture
model_json = model.to_json()
path_to_architecture = path_to_training + "/model.json"
with open(path_to_architecture, "w") as json_file:
    json_file.write(model_json)
print("Save model architecture to {}".format(path_to_architecture))

# Checkpoint for trained model
checkpoint = ModelCheckpoint(
    path_to_training+'/weights.hdf5',
    monitor='val_loss', verbose=1, save_best_only=True)
csv_logger = CSVLogger(path_to_training+'/training.log')

callbacks_list = [checkpoint, csv_logger]
# Out:
# Save training context to ./models/unets/training_6/context.log
# Save model architecture to ./models/unets/training_6/model.json

# %%
model.fit_generator(train_gen,epochs=epoches, steps_per_epoch=5600 // batch_size,
                    callbacks=callbacks_list, validation_data=val_gen, validation_steps= 2000// batch_size)
# Out:
# Epoch 1/10000
#  20/112 [====>.........................] - ETA: 27:05 - loss: 3.9863 - my_mean_squared_error: 478.3070 - mean_squared_error: 478.3070 - mean_absolute_error: 3.9863 - l2_on_wedge: 277.6668 - my_psnr: -12.4539
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-23-575b8b657aa8> in <module>
#       1 model.fit_generator(train_gen,epochs=epoches, steps_per_epoch=5600 // batch_size,
# ----> 2                     callbacks=callbacks_list, validation_data=val_gen, validation_steps= 2000// batch_size)
#
# ~/store/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1777         use_multiprocessing=use_multiprocessing,
#    1778         shuffle=shuffle,
# -> 1779         initial_epoch=initial_epoch)
#    1780
#    1781   def evaluate_generator(self,
#
# ~/store/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     173       batch_index = 0
#     174       while steps_done < steps_per_epoch:
# --> 175         generator_output = next(output_generator)
#     176
#     177         if not hasattr(generator_output, '__len__'):
#
# ~/store/miniconda3/envs/tf_gpu/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py in get(self)
#     816           raise StopIteration()
#     817         else:
# --> 818           time.sleep(self.wait_time)
#     819
#     820     # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:
